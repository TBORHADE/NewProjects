# %% [markdown]
# # HealthCare EDA

# %%
# import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# import csv file and create dataframe

# %%
df = pd.read_csv('rows.csv')
df
# Out:
#          index Provider ID                      Hospital Name  \
# 0            0       10005      MARSHALL MEDICAL CENTER SOUTH
# 1            1       10005      MARSHALL MEDICAL CENTER SOUTH
# 2            2       10005      MARSHALL MEDICAL CENTER SOUTH
# 3            3       10005      MARSHALL MEDICAL CENTER SOUTH
# 4            4       10005      MARSHALL MEDICAL CENTER SOUTH
# ...        ...         ...                                ...
# 180758  180758      250061         YALOBUSHA GENERAL HOSPITAL
# 180759  180759       50590   METHODIST HOSPITAL OF SACRAMENTO
# 180760  180760      150150                DUPONT HOSPITAL LLC
# 180761  180761       50739  CENTINELA HOSPITAL MEDICAL CENTER
# 180762  180762      340173             WAKEMED, CARY HOSPITAL
#
#                            Address          City State  ZIP Code  County Name  \
# 0       2505 U S HIGHWAY 431 NORTH          BOAZ    AL     35957     MARSHALL
# ...

# %%
new_df = df.head(5000)

# %%
new_df
# Out:
#       index Provider ID                  Hospital Name  \
# 0         0       10005  MARSHALL MEDICAL CENTER SOUTH
# 1         1       10005  MARSHALL MEDICAL CENTER SOUTH
# 2         2       10005  MARSHALL MEDICAL CENTER SOUTH
# 3         3       10005  MARSHALL MEDICAL CENTER SOUTH
# 4         4       10005  MARSHALL MEDICAL CENTER SOUTH
# ...     ...         ...                            ...
# 4995   4995      280009      CHI HEALTH GOOD SAMARITAN
# 4996   4996      280009      CHI HEALTH GOOD SAMARITAN
# 4997   4997      280009      CHI HEALTH GOOD SAMARITAN
# 4998   4998      280009      CHI HEALTH GOOD SAMARITAN
# 4999   4999      280009      CHI HEALTH GOOD SAMARITAN
#
#                             Address     City State  ZIP Code County Name  \
# 0        2505 U S HIGHWAY 431 NORTH     BOAZ    AL     35957    MARSHALL
# 1        2505 U S HIGHWAY 431 NORTH     BOAZ    AL     35957    MARSHALL
# 2        2505 U S HIGHWAY 431 NORTH     BOAZ    AL     35957    MARSHALL
# ...

# %%
new_df.columns
# Out:
# Index(['index', 'Provider ID', 'Hospital Name', 'Address', 'City', 'State',
#        'ZIP Code', 'County Name', 'Phone Number', 'Condition', 'Measure ID',
#        'Measure Name', 'Score', 'Sample', 'Footnote', 'Measure Start Date',
#        'Measure End Date', 'Location'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['index', 'Provider ID', 'Hospital Name', 'Address', 'City', 'State',
#        'ZIP Code', 'County Name', 'Phone Number', 'Condition', 'Measure ID',
#        'Measure Name', 'Score', 'Sample', 'Footnote', 'Measure Start Date',
#        'Measure End Date', 'Location'],
#       dtype='object')

# %%
df.head(1).T
# Out:
#                                                                     0
# index                                                               0
# Provider ID                                                     10005
# Hospital Name                           MARSHALL MEDICAL CENTER SOUTH
# Address                                    2505 U S HIGHWAY 431 NORTH
# City                                                             BOAZ
# State                                                              AL
# ZIP Code                                                        35957
# County Name                                                  MARSHALL
# Phone Number                                               2565938310
# Condition                                  Heart Attack or Chest Pain
# Measure ID                                                     AMI_7a
# Measure Name        Fibrinolytic Therapy Received Within 30 Minute...
# ...

# %%
# information about a DataFrame including the index dtype and columns, non-null values and memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180763 entries, 0 to 180762
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               180763 non-null  int64
#  1   Provider ID         180763 non-null  object
#  2   Hospital Name       180763 non-null  object
#  3   Address             180763 non-null  object
#  4   City                180763 non-null  object
#  5   State               180763 non-null  object
#  6   ZIP Code            180763 non-null  int64
#  7   County Name         180330 non-null  object
#  8   Phone Number        180763 non-null  int64
#  9   Condition           180763 non-null  object
#  10  Measure ID          180763 non-null  object
#  11  Measure Name        180763 non-null  object
#  12  Score               180763 non-null  object
#  13  Sample              176125 non-null  object
#  14  Footnote            139495 non-null  object
# ...

# %%
#sum of null values in columns

# %%
df.isna().sum()
# Out:
# index                     0
# Provider ID               0
# Hospital Name             0
# Address                   0
# City                      0
# State                     0
# ZIP Code                  0
# County Name             433
# Phone Number              0
# Condition                 0
# Measure ID                0
# Measure Name              0
# Score                     0
# Sample                 4638
# Footnote              41268
# Measure Start Date        0
# Measure End Date          0
# Location                  0
# dtype: int64

# %%
df.isna().mean()
# Out:
# index                 0.000000
# Provider ID           0.000000
# Hospital Name         0.000000
# Address               0.000000
# City                  0.000000
# State                 0.000000
# ZIP Code              0.000000
# County Name           0.002395
# Phone Number          0.000000
# Condition             0.000000
# Measure ID            0.000000
# Measure Name          0.000000
# Score                 0.000000
# Sample                0.025658
# Footnote              0.228299
# Measure Start Date    0.000000
# Measure End Date      0.000000
# Location              0.000000
# dtype: float64

# %%
df.isna().mean()*100
# Out:
# index                  0.000000
# Provider ID            0.000000
# Hospital Name          0.000000
# Address                0.000000
# City                   0.000000
# State                  0.000000
# ZIP Code               0.000000
# County Name            0.239540
# Phone Number           0.000000
# Condition              0.000000
# Measure ID             0.000000
# Measure Name           0.000000
# Score                  0.000000
# Sample                 2.565791
# Footnote              22.829893
# Measure Start Date     0.000000
# Measure End Date       0.000000
# Location               0.000000
# dtype: float64

# %%
df.fillna('Nan', inplace = False)

# %%
# hospital _name

# %%
df['Hospital Name']
# Out:
# 0             MARSHALL MEDICAL CENTER SOUTH
# 1             MARSHALL MEDICAL CENTER SOUTH
# 2             MARSHALL MEDICAL CENTER SOUTH
# 3             MARSHALL MEDICAL CENTER SOUTH
# 4             MARSHALL MEDICAL CENTER SOUTH
#                         ...
# 180758           YALOBUSHA GENERAL HOSPITAL
# 180759     METHODIST HOSPITAL OF SACRAMENTO
# 180760                  DUPONT HOSPITAL LLC
# 180761    CENTINELA HOSPITAL MEDICAL CENTER
# 180762               WAKEMED, CARY HOSPITAL
# Name: Hospital Name, Length: 180763, dtype: object

# %%
df['Hospital Name'].unique()
# Out:
# array(['MARSHALL MEDICAL CENTER SOUTH', 'DEKALB REGIONAL MEDICAL CENTER',
#        'WEDOWEE HOSPITAL', ..., 'SIOUX FALLS VA MEDICAL CENTER',
#        'CANANDAIGUA VA MEDICAL CENTER',
#        'COOK CHILDRENS NORTHEAST HOSPITAL, LLC'], dtype=object)

# %%
df['Hospital Name'].nunique()
# Out:
# 4605

# %%
df['Hospital Name'].value_counts()
# Out:
# MEMORIAL HOSPITAL                          506
# ST JOSEPH HOSPITAL                         317
# GOOD SAMARITAN HOSPITAL                    280
# ST FRANCIS HOSPITAL                        240
# MERCY HOSPITAL                             239
#                                           ...
# ED FRASER MEMORIAL HOSPITAL                  9
# HOLY CROSS GERMANTOWN HOSPITAL               9
# ASPIRE BEHAVIORAL HEALTH OF CONROE, LLC      9
# COOK CHILDRENS NORTHEAST HOSPITAL, LLC       2
# SONOMA DEVELOPMENTAL CENTER                  1
# Name: Hospital Name, Length: 4605, dtype: int64

# %%
#state

# %%
df['State'].value_counts()
# Out:
# TX    14258
# CA    12773
# FL     7180
# IL     6940
# NY     6867
# PA     6714
# OH     6404
# MI     5287
# GA     5084
# MN     5060
# OK     4937
# IN     4874
# WI     4792
# KS     4714
# LA     4470
# IA     4299
# TN     4250
# NC     4175
# MO     3983
# MS     3715
# KY     3698
# AL     3543
# NE     3488
# WA     3436
# VA     3223
# AZ     2960
# CO     2946
# AR     2804
# NJ     2573
# MA     2442
# SC     2409
# OR     2264
# MT     1921
# WV     1864
# MD     1827
# SD     1794
# UT     1785
# ND     1716
# NM     1539
# PR     1441
# ID     1439
# NV     1340
# ME     1298
# CT     1203
# NH      987
# WY      984
# AK      720
# HI      683
# VT      485
# RI      452
# DC      323
# DE      251
# VI       69
# GU       40
# MP       29
# AS       11
# Name: State, dtype: int64

# %%
df['State'].value_counts().head(10)
# Out:
# TX    14258
# CA    12773
# FL     7180
# IL     6940
# NY     6867
# PA     6714
# OH     6404
# MI     5287
# GA     5084
# MN     5060
# Name: State, dtype: int64

# %%
#measure name

# %%
df['Measure Name'].value_counts()
# Out:
# Fibrinolytic Therapy Received Within 30 Minutes Of Hospital Arrival                                                                        4772
# Initial antibiotic selection for CAP in immunocompetent patient                                                                            4772
# Surgery Patients Who Received Appropriate Venous Thromboembolism Prophylaxis Within 24 Hours Prior to Surgery to 24 Hours After Surgery    4772
# Postoperative Urinary Catheter Removal                                                                                                     4772
# Prophylactic antibiotics discontinued within 24 hours after surgery end time                                                               4772
# Prophylactic Antibiotic Selection for Surgical Patients                                                                                    4772
# ...

# %%
#footnote

# %%
df['Footnote'].value_counts()
# Out:
# 5 - Results are not available for this reporting period.                                                                                                                               41672
# 2 - Data submitted were based on a sample of cases/patients.                                                                                                                           28644
# 3 - Results are based on a shorter time period than required.                                                                                                                          15705
# 2 - Data submitted were based on a sample of cases/patients., 3 - Results are based on a shorter time period than required.                                                            13134
# 1 - The number of cases/patients is too few to report., 3 - Results are based on a shorter time period than required.                                                                   9342
# ...

# %%
df['Footnote'].value_counts().head(10)
# Out:
# 5 - Results are not available for this reporting period.                                                                       41672
# 2 - Data submitted were based on a sample of cases/patients.                                                                   28644
# 3 - Results are based on a shorter time period than required.                                                                  15705
# 2 - Data submitted were based on a sample of cases/patients., 3 - Results are based on a shorter time period than required.    13134
# 1 - The number of cases/patients is too few to report., 3 - Results are based on a shorter time period than required.           9342
# 1 - The number of cases/patients is too few to report.                                                                          8430
# 3 - Results are based on a shorter time period than required., 7 - No cases met the criteria for this measure.                  7297
# ...

# %%
#city

# %%
df['City'].value_counts()
# Out:
# CHICAGO         1052
# HOUSTON          891
# PHILADELPHIA     711
# LOS ANGELES      691
# DALLAS           691
#                 ...
# HINES             11
# HUMBOLDT          11
# MACCLENNY          9
# HURST              2
# ELDRIDGE           1
# Name: City, Length: 2913, dtype: int64

# %%
df['City'].value_counts().head(20)
# Out:
# CHICAGO          1052
# HOUSTON           891
# PHILADELPHIA      711
# LOS ANGELES       691
# DALLAS            691
# OKLAHOMA CITY     652
# WASHINGTON        630
# SPRINGFIELD       619
# COLUMBUS          618
# JACKSON           600
# PHOENIX           591
# BALTIMORE         575
# BROOKLYN          520
# GREENVILLE        518
# COLUMBIA          502
# SAN ANTONIO       484
# LAFAYETTE         480
# JACKSONVILLE      470
# NEW YORK          453
# INDIANAPOLIS      451
# Name: City, dtype: int64

# %%
#location

# %%
df['Location'].value_counts()
# Out:
# 155 MEMORIAL DRIVE\nPINEHURST, NC 28374\n(35.206598, -79.45811)                    41
# 1214 COOLIDGE AVENUE\nLAFAYETTE, LA 70503\n(30.202319, -92.018705)                 41
# 2211 LOMAS BOULEVARD NE\nALBUQUERQUE, NM 87106\n(35.087483, -106.618148)           41
# 901 E 18TH STREET\nTIFTON, GA 31793\n(31.470265, -83.489613)                       41
# 1415 ROSS AVENUE\nEL CENTRO, CA 92243\n(32.781498, -115.56862)                     41
#                                                                                    ..
# 2006 SOUTH LOOP 336 WEST, SUITE 500\nCONROE, TX 77304\n(30.284069, -95.480131)      9
# 159 N 3RD ST\nMACCLENNY, FL 32063\n(30.28555, -82.11955)                            9
# 19801 OBSERVATION DRIVE\nGERMANTOWN, MD 20876\n(39.18119, -77.244853)               9
# 6316 PRECINCT LINE RD\nHURST, TX 76054\n(32.863373, -97.186132)                     2
# 15000 ARNOLD DRIVE / P O BOX 1493\nELDRIDGE, CA 95431\n(38.349023, -122.516906)     1
# ...

# %%
df['Location'].value_counts().head(20)
# Out:
# 155 MEMORIAL DRIVE\nPINEHURST, NC 28374\n(35.206598, -79.45811)                        41
# 1214 COOLIDGE AVENUE\nLAFAYETTE, LA 70503\n(30.202319, -92.018705)                     41
# 2211 LOMAS BOULEVARD NE\nALBUQUERQUE, NM 87106\n(35.087483, -106.618148)               41
# 901 E 18TH STREET\nTIFTON, GA 31793\n(31.470265, -83.489613)                           41
# 1415 ROSS AVENUE\nEL CENTRO, CA 92243\n(32.781498, -115.56862)                         41
# 1000 MAR-WALT DR\nFORT WALTON BEACH, FL 32547\n(30.454676, -86.632069)                 41
# 4940 EASTERN AVENUE\nBALTIMORE, MD 21224\n(39.287285, -76.552134)                      41
# 509 BILTMORE AVE\nASHEVILLE, NC 28801\n(35.577942, -82.54837)                          41
# 309 JACKSON STREET\nMONROE, LA 71201\n(32.499732, -92.11479)                           41
# 254 EASTON AVE\nNEW BRUNSWICK, NJ 08901\n(40.501846, -74.45913)                        41
# ...

# %%
#score

# %%
df['Score'].value_counts()
# Out:
# Not Available    81971
# 100              28461
# 99                7964
# 98                5917
# 97                4228
#                  ...
# 810                  1
# 795                  1
# 764                  1
# 572                  1
# 656                  1
# Name: Score, Length: 588, dtype: int64

# %%
df['Score'].value_counts().head(20)
# Out:
# Not Available                                 81971
# 100                                           28461
# 99                                             7964
# 98                                             5917
# 97                                             4228
# 96                                             3273
# 95                                             2713
# 0                                              2420
# 94                                             2148
# 93                                             1744
# 92                                             1592
# 1                                              1563
# 91                                             1264
# 2                                              1113
# Low (0 - 19,999 patients annually)             1036
# 90                                              989
# Medium (20,000 - 39,999 patients annually)      980
# 89                                              889
# ...

# %%
#replacing missing values

# %%
df['score'].replace({"Not Available": 95,
                    "Low (0 - 19,999 patients annually)":10,
                    "Medium (20,000 - 39,999 patients annually)":25
                    ""})
